# %%
import pandas as pd
df = pd.read_csv("cleaned_data(1).csv")

# %%
df.head()
# Out:
#    Unnamed: 0                User  \
# 0           0         Karen Gulli
# 1           1        Ronny Magadi
# 2           2  Hushikesh Suvakiya
# 3           3       Mann Official
# 4           4     ashutosh gokani
#
#                                               Review  Rating  Likes  Year  \
# 0                                               Good       3      0  2024
# 1  App is useful to certain phone brand ,,,,it is...       1      0  2024
# 2                 Always promoting anti-Hindu shows.       1      8  2024
# 3  No I'm not able to remove this app anymore 0 o...       1      0  2024
# 4  Thy are supporting maharaj movie ...thts not a...       1      9  2024
#
#   virality
# 0  level 1
# 1  level 1
# 2  level 1
# 3  level 1
# 4  level 1

# %%
df['virality'].value_counts()['level 5']  # Count occurrences of 'level 1' in 'virality' column
# Out:
# 250

# %%
ctr = 0
for index, row in df.iterrows():
  if row['Rating'] == 5:
    ctr +=1
    print(row['Review'], "\n")
    print(ctr, "\n")
    if ctr == 25:
      break
# Out:
# I love cause it has what i want go Netflix but where's the originals and legacies please put it soon
#
# 1
#
# Ok
#
# 2
#
# maybe i share my experience to how use the netflix, it because so beautiful but very hard how to create an account, but solid haha
#
# 3
#
# Nice 👍
#
# 4
#
# good
#
# 5
#
# I love this Netflix
#
# 6
#
# Where is Godzilla 2014 movie
#
# 7
#
# Great service
#
# 8
#
# Good
#
# 9
#
# Good
#
# 10
#
# wakeelAhmadineja
#
# 11
#
# Best app fOr movies
#
# 12
#
# hhaha
#
# 13
#
# The bloodline Roman Reigns Jackie Redmond wwe
#
# 14
#
# I love to watch the movie's you have on here and the TV shows I love them 💗💗💗
#
# 15
#
# Good
#
# 16
#
# Love it once a year or two
#
# 17
#
# So great & reliable
#
# 18
#
# Netflix Jan 14 2015
#
# 19
#
# its netflix nothing rong with it
#
# 20
#
# It is very good 😃😃🙃
#
# 21
#
# Great app it is
#
# 22
#
# ...

# %%
for i in df.values:
  anc = i[0]
  pos = list(i[[1, 2]])
  neg = list(i[3:])
  print(pos , "\n")
# Out:
# ["Dennis Lingo Men's Slim Fit Checkered Green Casual Shirt", "Dennis Lingo Men's Solid Slim Fit Cotton Casual Shirt with Spread Collar & Full Sleeves This Casual Solid shirt has a Slim fit, Spread collar, full button Placket, Full Sleeves, and a curved hemline Size and Fit Slim Fit The Model (height 6 foot and shoulders 18 inches is wearing size 40/M Please check the size chart for more details before ordering Material & Care 100% Premium Cotton (Machine Wash Regular) Style Tip Enhance your look by wearing this Casual Stylish Men's shirt, Team it with a pair of Chinos or Tapered Denim and Sneakers for a fun Smart Casual look About the Brand DENNIS LINGO Finding Basic Menswear for daily use can be hard among todays Fast fashion world, where trends change daily. That’s why we started Dennis Lingo, to create a one stop shop for premium essential clothing for everyday use at lowest prices"]
#
# ...
